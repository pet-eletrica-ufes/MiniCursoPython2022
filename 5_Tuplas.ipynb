# %% [markdown]
# <a href="https://colab.research.google.com/github/PetEletricaUfes/MiniCursoPython/blob/main/5_Tuplas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ><a href="https://www.ufes.br/">
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/1/1a/Bras%C3%A3o_Ufes.svg/1200px-Bras%C3%A3o_Ufes.svg.png" alt="Drawing" width="85"></a>
# <img width="80">
# <a href="https://www.peteletrica.ufes.br/">
# <img src="https://www.peteletrica.ufes.br/wp-content/uploads/2020/07/cropped-cropped-cropped-logo-pet-branca.png" alt="Drawing" width="280"></a>  <center>

# %% [markdown]
# # Lesson 05: Tuplas

# %% [markdown]
# # Introdução

# %% [markdown]
# >São estruturas de dados parecidas com listas, mas com a particularidade de serem **imutáveis.**
#
# >Tuplas são sequências e, assim como listas, podem ser indexadas e fatiadas, mas **não é possível modificá-las.**
#
# >Um valor do tipo tupla é uma série de valores separados por vírgulas e entre parênteses.

# %%
x = (1,2,3)
print(x)
# Out:
# (1, 2, 3)

# %%
x[0]=1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-2-7215f83d98c8> in <module>()
# ----> 1 x[0]=1
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# # A função **tuple**

# %% [markdown]
# >A função tuple constrói uma tupla a partir de uma sequência qualquer

# %%
tuple("abcdefg")
# Out:
# ('a', 'b', 'c', 'd', 'e', 'f', 'g')

# %%
tuple([1,2,3])
# Out:
# (1, 2, 3)

# %% [markdown]
# # Formatando tuplas

# %% [markdown]
# >Um **template** pode ser aplicado aos diversos valores de uma tupla para construir uma string formatada

# %%
template = ("%s tem %d anos")
tupla = ('Pedro',10)
print(template % tupla)
# Out:
# Pedro tem 10 anos

# %% [markdown]
# #Atribuição de tuplas

# %% [markdown]
# > De vez em quando, é necessário **trocar entre si os valores de duas variáveis**.Com operações de atribuição convencionais, temos que utilizar uma variável temporária. Python fornece uma **forma de atribuição de tupla** que resolve esse problema elegantemente:

# %%
a=1000
b=1
temp = a
a = b
b = temp
print("Valor de a: ", a)
print("Valor de b: ", b)
# Out:
# Valor de a:  1
# Valor de b:  1000

# %%
a=1000
b=1
a , b = b , a
print("Valor de a: ", a)
print("Valor de b: ", b)
# Out:
# Valor de a:  1
# Valor de b:  1000

# %% [markdown]
# # Especificações de formato

# %%
from math import pi
print("Ponto flutuante: %f" % pi)
print("Ponto flutuante com 20 casas decimais: ||%.20f||" % pi)
print("Ponto flutuante com 10 caracteres: ||%10f||" % pi )
print("Ponto flutuante com 10 caracteres e 2 casas decimais: ||%10.2f||" % pi )
print("Ponto flutuante em notacao cientifica: ||%10e||" % pi )
# Out:
# Ponto flutuante: 3.141593
# Ponto flutuante com 20 casas decimais: ||3.14159265358979311600||
# Ponto flutuante com 10 caracteres: ||  3.141593||
# Ponto flutuante com 10 caracteres e 2 casas decimais: ||      3.14||
# Ponto flutuante em notacao cientifica: ||3.141593e+00||

# %% [markdown]
# # Exercício de fixação

# %% [markdown]
# >Construa uma mini tabela de preços:
#
# Item      |       Preco
# :------------ | :-----:
# Maca |       2.00
# Pera  |      3.50
# Maca verde | 5.90

# %%
Itens = ["Maca","Pera","Maca verde"]
Precos = [2.0, 3.5, 5.90]

len_precos = 10 # Coluna de precos tem 10 caracteres
# len é uma abreviação de lenght
# lenght = comprimento

# Achar o comprimento da coluna de itens 
len_itens = len( Itens[0] )
for it in Itens :
  len_itens = max( len_itens, len(it) )

# Imprimir tabela de precos

# Imprimi uma linha com (len_itens + len_precos) caracteres, e esses caracteres são iguais a "-"
print("-" * (len_itens + len_precos))
print("%-*s%*s" % (len_itens, "Item", len_precos, "Preco"))
print("-" * (len_itens + len_precos))
for i in range (len(Itens)) :
  print("%-*s%*.2f" % (len_itens, Itens[i], len_precos, Precos[i]) )
# Out:
# --------------------
# Item           Preco
# --------------------
# Maca            2.00
# Pera            3.50
# Maca verde      5.90
